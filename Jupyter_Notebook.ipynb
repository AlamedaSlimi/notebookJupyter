# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# <h1>Jupyter Notebook</h1>

# %% [markdown]
# In this notebook, we are testing the tools in jupyter notebook.

# %% [markdown]
# Some of the most used programming languages in data science are:
# 1. Python
# 2. R
# 3. C++
# 4. Matlab

# %% [markdown]
# Some of the commonly used libraries in data science are:
# 1. Pandas
# 2. Scikit-learn
# 3. Matplotlib
# 4. Numpy

# %% [markdown]
# Some of the data science tools are:
#
# |        Data Science Toools     |
# |:------------------------------:|
# |  Excel   |
# |  Visual Studio Code   |
# |  Github   |

# %% [markdown]
# <h3>Below are a few examples of evaluating aritmetic expressions in python:</h3>

# %%
#Sums
x = 2+3
print(x)

#Restas
x = 2-3
print(x)

#Multiply
x = (3*4)+5
print(x)
# Out:
# 5
# -1
# 17

# %%
#This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes/60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
# 1. Learning python
# 2. Learning tools
# 3. Learning libraries

# %% [markdown]
# <h2>Author: Saul Jimenez</h2>
